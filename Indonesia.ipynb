# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaFernandaOrtega/ML-Project/blob/main/Indonesia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
df_indo = pd.read_excel(io.BytesIO(uploaded['test1.xlsx']))
df_indo = pd.DataFrame(df_indo)
df_indo= pd.read_excel('test1.xlsx')
df_indo
# Out:
#      <input type="file" id="files-e959ecf5-54a4-4b06-b63a-26de571628bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e959ecf5-54a4-4b06-b63a-26de571628bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
import io
df_indo2 = pd.read_excel(io.BytesIO(uploaded['indo2.xlsx']))
df_indo2 = pd.DataFrame(df_indo2)
df_indo2= pd.read_excel('indo2.xlsx')
df_indo2
# Out:
#      <input type="file" id="files-9c1c2a1c-895f-4ad2-99f9-7b1b814f862a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c1c2a1c-895f-4ad2-99f9-7b1b814f862a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
check = ['Legit']
df_indo['check'] = df_indo['Label'].isin(check).astype(int)
df_indo
# Out:
#             Domain                                              Topic  \
# 0        Celebrity  https://www.vanityfair.com/style/2017/09/jim-c...
# 1         Politics  AQAP berusaha menyembunyikan bahan peledak dal...
# 2    Entertainment  Membakar Bayi Membakar George Michael potret y...
# 3        Celebrity  Kim Kardashian Menyewa Tim Untuk membantunya M...
# 4    Entertainment  Will Smith bersatu kembali dengan Fresh Prince...
# ..             ...                                                ...
# 387         Sports   Jersey Tom Brady Dibeli di Yardsale di Tennessee
# 388      Celebrity  Victoria Beckham akhirnya menangani klaim bahw...
# 389      Celebrity  Kim Kardashian Cemburu pada Tubuh Bikini Kourt...
# 390      Celebrity  Kendall Jenner menangisi reaksi iklan Pepsi da...
# 391      Celebrity  David Foster Katharine McPhee Memalsukan Merek...
#
#                                                   News  Label  check
# ...

# %%
check = ['Legit']
df_indo2['check'] = df_indo2['Label'].isin(check).astype(int)
df_indo2
# Out:
#             Domain                                              Topic  \
# 0           Sports  Roger Federer mengalahkan Frances Tiafoe saat ...
# 1        Celebrity  'Sudah lama datang': Heidi Klum mengakhiri per...
# 2        Celebrity     Liam Payne Just Dissed Solo Music Harry Styles
# 3    Entertainment  Kita semua tahu mengapa orang benar marah pada...
# 4        Celebrity                       Di dalam baby shower Beyonce
# ..             ...                                                ...
# 583      Education  Survei Menunjukkan Aplikasi Perguruan Tinggi y...
# 584         Sports  Real Madrid mungkin tidak mau membayar £ 100 j...
# 585      Celebrity  Caitlyn Jenner: Robert Kardashian Diyakini OJ ...
# 586       Business  Jutaan pekerja Inggris berisiko digantikan ole...
# 587     Technology  Netflix sedang menguji iklan, dan pemirsa memb...
#
#                                                   News  Label  check
# ...

# %%
df_final_indo = pd.concat([df_indo, df_indo2]).reset_index(drop = True)
df_final_indo
# Out:
#             Domain                                              Topic  \
# 0        Celebrity  https://www.vanityfair.com/style/2017/09/jim-c...
# 1         Politics  AQAP berusaha menyembunyikan bahan peledak dal...
# 2    Entertainment  Membakar Bayi Membakar George Michael potret y...
# 3        Celebrity  Kim Kardashian Menyewa Tim Untuk membantunya M...
# 4    Entertainment  Will Smith bersatu kembali dengan Fresh Prince...
# ..             ...                                                ...
# 975      Education  Survei Menunjukkan Aplikasi Perguruan Tinggi y...
# 976         Sports  Real Madrid mungkin tidak mau membayar £ 100 j...
# 977      Celebrity  Caitlyn Jenner: Robert Kardashian Diyakini OJ ...
# 978       Business  Jutaan pekerja Inggris berisiko digantikan ole...
# 979     Technology  Netflix sedang menguji iklan, dan pemirsa memb...
#
#                                                   News  Label  check
# ...

# %% [markdown]
# Tokenize Text

# %%
import nltk
import gensim
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('stopwords')
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
